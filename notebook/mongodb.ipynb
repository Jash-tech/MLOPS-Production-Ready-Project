# %%
"""mongodb+srv://jashsuke:IPaW2zMIkKklmQJN@cluster0.n84di08.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"""
# Out:
# 'mongodb+srv://jashsuke:IPaW2zMIkKklmQJN@cluster0.n84di08.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pandas as pd

# %%
data=pd.read_csv('EasyVisa.csv')
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data.shape
# Out:
# (25480, 12)

# %%
df=data.to_dict(orient="records")

# %%
df[0]
# Out:
# {'case_id': 'EZYV01',
#  'continent': 'Asia',
#  'education_of_employee': 'High School',
#  'has_job_experience': 'N',
#  'requires_job_training': 'N',
#  'no_of_employees': 14513,
#  'yr_of_estab': 2007,
#  'region_of_employment': 'West',
#  'prevailing_wage': 592.2029,
#  'unit_of_wage': 'Hour',
#  'full_time_position': 'Y',
#  'case_status': 'Denied'}

# %%
DB_NAME='us_visa_db'
COLLECTION_NAME='us_visa_collection'
COLLECTION_URL='mongodb+srv://jashsuke:IPaW2zMIkKklmQJN@cluster0.n84di08.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pymongo

# %%
client=pymongo.MongoClient(COLLECTION_URL)
database_name=client[DB_NAME]
collection_name=database_name[COLLECTION_NAME]
rec=collection_name.insert_many(df)

# %%
records=collection_name.find()

# %%
df1=pd.DataFrame(list(collection_name.find()))
df1.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  6689a77b64d6546094ec882f  EZYV01      Asia           High School
# 1  6689a77b64d6546094ec8830  EZYV02      Asia              Master's
# 2  6689a77b64d6546094ec8831  EZYV03      Asia            Bachelor's
# 3  6689a77b64d6546094ec8832  EZYV04      Asia            Bachelor's
# 4  6689a77b64d6546094ec8833  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
if '_id' in list(df1.columns):
    df1=df1.drop(columns='_id',axis=1)

# %%
df1.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...
